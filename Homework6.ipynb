# %% [markdown]
# # DSU 1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu1.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
pts2 = np.float32([[578,336],[598,557],[740,380],[765,557]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 2

# %%
img = cv2.imread('dsu2.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
pts2 = np.float32([[578,336],[588,547],[755,376],[765,541]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 3

# %%
img = cv2.imread('dsu3.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,231],[570,457]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 4

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 5

# %%
img = cv2.imread('dsu5.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
pts2 = np.float32([[578,336],[588,547],[755,336],[765,541]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 6

# %%
img = cv2.imread('dsu6.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
pts2 = np.float32([[578,336],[588,507],[755,336],[765,601]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 7

# %%
img = cv2.imread('dsu7.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 8

# %%
img = cv2.imread('dsu8.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,250],[570,270],[570,457]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
