# %% [markdown]
# # DSU 1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu1.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[326,282],[326,537],[761,312],[767,512]])
pts2 = np.float32([[326,282],[326,537],[761,282],[761,537]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# ## DUS 2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu2.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[179,503],[181,243],[824,222],[822,508]])
pts2 = np.float32([[179,503],[179,243],[761,243],[761,503]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 3

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu2.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[110,497],[107,232],[703,164],[703,540]])
pts2 = np.float32([[110,497],[107,232],[761,232],[761,497]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 4

# %%
img = cv2.imread('dsu2.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[239,462],[239,269],[568,234],[570,497]])
pts2 = np.float32([[239,462],[239,269],[568,269],[570,462]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# ### DSU 5

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# img = cv2.imread('dsu5.jpg',1)
# rows,cols,ch = img.shape
# pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
# pts2 = np.float32([[578,336],[588,547],[755,336],[765,541]])
# M =  cv2.getPerspectiveTransform(pts1,pts2)
# dst = cv2.warpPerspective(img,M,(cols,rows))
# plt.subplot(121),plt.imshow(img),plt.title('Input')
# plt.subplot(122),plt.imshow(dst),plt.title('Output')
# plt.show()

# %% [markdown]
# # DSU 6

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu6.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[462,579],[546,366],[671,383],[643,551]])
pts2 = np.float32([[462,579],[546,366],[671,366],[643,579]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# # DSU 7

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu7.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[292,525],[295,405],[536,413],[531,531]])
pts2 = np.float32([[292,525],[295,405],[536,413],[531,525]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# ## DSU 8

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu8.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[164,572],[172,443],[449,445],[488,592]])
pts2 = np.float32([[164,572],[172,443],[449,443],[488,572]])
M =  cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
